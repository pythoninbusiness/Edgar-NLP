# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from Helpers import load, textpreprocess
import pandas as pd
import re

# %% [markdown]
# # Load Data:

# %%
edgar_filing_urls = [
    "https://www.sec.gov/ix?doc=/Archives/edgar/data/1093691/000155837021010611/plug-20210630x10q.htm", "https://www.sec.gov/ix?doc=/Archives/edgar/data/1655210/000165521021000181/bynd-20210703.htm", 
    "https://www.sec.gov/ix?doc=/Archives/edgar/data/1800667/000095017021001008/frog-20210630.htm", "https://www.sec.gov/ix?doc=/Archives/edgar/data/1517413/000151741321000154/fsly-20210630.htm",
    "https://www.sec.gov/ix?doc=/Archives/edgar/data/1691421/000169142121000081/lmnd-20210630.htm", "https://www.sec.gov/Archives/edgar/data/1617640/000161764021000055/z-20210630.htm",
    "https://www.sec.gov/ix?doc=/Archives/edgar/data/1679688/000167968821000085/dbrg-20210630.htm", "https://www.sec.gov/ix?doc=/Archives/edgar/data/1734722/000173472221000009/path-20210731.htm"
]
edgar_filing_url = edgar_filing_urls[-1]

# %%
entry_soup = load.load_soup_from_file_or_edgar(edgar_filing_url)
full_text = textpreprocess.get_text_from_soup(entry_soup)
sentences = textpreprocess.split_into_sentences(full_text)
sentences = [sentence for sentence in sentences if len(sentence.split(" ")) > 7]
cleaned_sentences = textpreprocess.lemmatize_sentences_and_remove_stop_words(sentences, remove_digits=True, additional_stop_words=["—"])

# %% [markdown]
# # Fit Model

# %%
vectorizer = TfidfVectorizer().fit(cleaned_sentences)
sentence_vectors = vectorizer.transform(cleaned_sentences).toarray()

# %% [markdown]
# # Using Pandas to filter similar paragraphs using the cosine similarity

# %%
df = pd.DataFrame(cosine_similarity(sentence_vectors))
df = df.reset_index()
df = df.melt("index")
df.columns = ["TextIndex", "ComparedToIndex", "Similarity"]

# %%
similar_sentences = df.query(".8 < Similarity < .96 and TextIndex != ComparedToIndex")

similar_text_tuple = set()

# this is a list comprehension to add paragraphs to a tuple. Because cosine similarity has duplicate values where TextOne and TextTwo will be swapped. So this makes sure our pairs are unique
temp_ = [similar_text_tuple.add((a, b, c)) for (a, b, c) in similar_sentences[["TextIndex", "ComparedToIndex", "Similarity"]].values if (a, b, c) and (b, a, c) not in similar_text_tuple]

similar_text_df = pd.DataFrame(similar_text_tuple)
similar_text_df.columns = ["TextIndex", "ComparedToIndex", "Similarity"]
similar_text_df["TextOne"] = similar_text_df["TextIndex"].apply(lambda x: sentences[x])
similar_text_df["TextTwo"] = similar_text_df["ComparedToIndex"].apply(lambda x: sentences[x])
similar_text_df["TextOneContext"] = similar_text_df["TextIndex"].apply(lambda x: " ".join(sentences[x-1: x+2]))

similar_text_df = similar_text_df[~similar_text_df["TextOne"].str.lower().str.contains("table")]
similar_text_df = similar_text_df[~similar_text_df["TextOne"].str.lower().str.contains("see note")]

if len(similar_text_df) > 80:
    similar_text_df = similar_text_df.drop_duplicates(keep="first", subset=["TextIndex"])

# to ensure that similar sentences are not in the same section
similar_text_df = similar_text_df.query("TextIndex - ComparedToIndex > 3").sort_values("Similarity")

# %%
similar_text_df
# Out:
#      TextIndex  ComparedToIndex  Similarity  \
# 82         672              384    0.801297
# 71         461              365    0.802081
# 87         465               45    0.804006
# 20         951              459    0.806133
# 69         342                8    0.806740
# 50         785              385    0.813276
# 75         672              385    0.813531
# 83         409              393    0.816916
# 43         540              516    0.818031
# 0          551              526    0.831068
# 38        1493               47    0.832579
# 55         933              396    0.834452
# 80         541              517    0.841859
# 100        566               48    0.847320
# 42         310              291    0.851760
# 47         740              728    0.852817
# 5         1388               95    0.852954
# 44        1386              461    0.853460
# 60         485              148    0.855467
# 89         542              520    0.867922
# 64         487              146    0.868661
# 46         487              482    0.868661
# 48         482              150    0.868661
# 85         150              146    0.868661
# 101        673              385    0.873469
# 34         542              527    0.874832
# 15        1432              602    0.878720
# 94        1386              365    0.882992
# 77        1386               93    0.900214
# 16         619               72    0.901605
# 49         187              176    0.903426
# 23         186              177    0.903426
# 59         176              172    0.903426
# 93         186              172    0.903426
# 81         461               93    0.908652
# 106        935              407    0.912111
# 30         711              367    0.914524
# 8          436              380    0.918924
# 84         489              484    0.919237
# 54        1289              667    0.932325
# 104       1396              668    0.935393
# 103        542              523    0.935423
# 79         542              529    0.935423
# 7          936              408    0.937198
# 21         822              655    0.937504
# 18        1172              664    0.941868
# 95         454              224    0.944253
# 22         486              149    0.945322
# 92         618               71    0.954395
# 45         542              518    0.956926
# 12         874              429    0.959518
# 61         875              429    0.959518
#
#                                                TextOne  \
# 82   Our annualized renewal run-rate, or ARR, was $...
# 71   Although these investments may adversely affec...
# 87   In addition, we offer a managed, multi-tenant,...
# 20   We cannot be certain when or if our operations...
# 69   These equity awards have an approximate aggreg...
# 50   We have experienced net losses in each fiscal ...
# 75   Our annualized renewal run-rate, or ARR, was $...
# 83   Moreover, ARR may differ from similarly titled...
# 43   Maintenance and support revenue is recognized ...
# 0    These increases were partially offset by a dec...
# 38   The recipients of the securities in this trans...
# 55   ARR does not include the costs we may incur to...
# 80   Cost of Revenue and Gross Margin Total cost of...
# 100  In April 2021, we completed our IPO, which res...
# 42   These adjustments caused a slight reduction in...
# 47   Our customers may also internally develop thei...
# 5    2014-09 (Topic 606), Revenue from Contracts wi...
# 44   Our revenue recognition policy and other facto...
# 60   We expect cost of maintenance and support reve...
# 89   The increase in cost of licenses revenue was p...
# 64   Cost of services and other revenue also includ...
# 46   Cost of services and other revenue also includ...
# 48   Cost of maintenance and support revenue also i...
# 85   Cost of services and other revenue also includ...
# 101  We generated revenue of $195.5 million and $13...
# 34   The increase in cost of licenses revenue was p...
# 15   We are an “emerging growth company,” and we ca...
# 94   Our revenue recognition policy and other facto...
# 77   Our revenue recognition policy and other facto...
# 16   Foreign Currency Exchange Risk The functional ...
# 49   Related amortization expense was $0.2 million ...
# 23   Capitalized software development costs were $3...
# 59   These capitalized costs are included in other ...
# 93   Capitalized software development costs were $3...
# 81   Although these investments may adversely affec...
# 106  As a result, ARR and our other operational dat...
# 30   Accordingly, our future success depends in par...
# 8    Our partner network includes, among others, Ac...
# 84   We recognize these expenses as they are incurr...
# 54   If we invest substantial time and resources to...
# 104  For more information on our revenue recognitio...
# 103  The increase in cost of licenses revenue was p...
# 79   The increase in cost of licenses revenue was p...
# 7    In addition, investors should not place undue ...
# 21   A limited number of customers represent a subs...
# 18   Any decreased use of our platform or products ...
# 95   For example, in March 2021, we acquired Cloud ...
# 22   Services and Other Cost of services and other ...
# 92   The effect of a hypothetical 10% change in int...
# 45   The increase in cost of licenses revenue was p...
# 12   Our enterprise sales force focuses on sales to...
# 61   As of July 31, 2021, we had 1,247 customers wi...
#
#                                                TextTwo
# 82   We generated revenue of $195.5 million and $13...
# 71   We generate revenue from the sale of licenses ...
# 87   Additionally, we offer maintenance and support...
# 20   We have a history of introducing successful ne...
# 69   Management’s Discussion and Analysis of Financ...
# 50   We generated revenue of $381.7 million and $25...
# 75   We generated revenue of $381.7 million and $25...
# 83   For further information, see the section title...
# 43   38 Table of Contents Cost of Revenue and Gross...
# 0    Research and Development 39 Table of Contents ...
# 38   Initial Public Offering On April 23, 2021, we ...
# 55   ARR does not include the costs we may incur to...
# 80   The increase in cost of licenses revenue was p...
# 100  We received net proceeds of $692.4 million aft...
# 42   As of July 31, 2021, total unrecognized compen...
# 47   This market may need further education on the ...
# 5    The amount of revenue recognized reflects the ...
# 44   Components of Results of Operations Revenue We...
# 60   12 Table of Contents UiPath, Inc. Notes to Con...
# 89   The increase in cost of services and other rev...
# 64   Overhead is allocated to cost of maintenance a...
# 46   Overhead is allocated to cost of maintenance a...
# 48   Overhead is allocated to cost of services and ...
# 85   Overhead is allocated to cost of maintenance a...
# 101  We generated revenue of $381.7 million and $25...
# 34   The increase was primarily attributable to an ...
# 15   JOBS Act Accounting Election We are an emergin...
# 94   We generate revenue from the sale of licenses ...
# 77   Revenue Recognition We derive our revenue from...
# 16   Asset and liability balances denominated in no...
# 49   Related amortization expense was $0.3 million ...
# 23   Related amortization expense for the six month...
# 59   Related amortization expense for the six month...
# 93   Related amortization expense for the six month...
# 81   Revenue Recognition We derive our revenue from...
# 106  In addition, investors should not place undue ...
# 30   Our license agreements generally have annual 3...
# 8    We provide tiering recognition through Diamond...
# 84   We expect cost of maintenance and support reve...
# 54   We and our independent registered public accou...
# 104  The dual class structure of our common stock h...
# 103  This increase was primarily attributable to an...
# 79   This increase was primarily attributable to an...
# 7    Moreover, ARR may differ from similarly titled...
# 21   If we fail to retain these customers, our reve...
# 18   Any failure to obtain, maintain, protect, or e...
# 95   The acquisition of Cloud Elements brings techn...
# 22   Cost of services and other revenue also includ...
# 92   Foreign Currency The functional currency of ou...
# 45   The increase in cost of maintenance and suppor...
# 12   For example, as of July 31, 2021, we had 1,247...
# 61   For example, as of July 31, 2021, we had 1,247...

# %%
similar_text_df.to_clipboard(index=False)
